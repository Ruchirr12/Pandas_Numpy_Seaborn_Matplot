# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ### 1. Numerical Data Ploting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...
#
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()

# %%
import seaborn as sns
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %% [markdown]
# # Seaborn has five built-in themes to style its plots: darkgrid, whitegrid, dark, white, and ticks

# %%
sns.set(style = 'darkgrid')

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x ='total_bill', y = 'tip', data = tips,height=4,aspect=3)
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue="sex", data = tips,height=6,aspect=2)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips["size"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', data = tips,height=6,aspect=2)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips,style="day",hue="sex",height=5,aspect=3)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips,hue = 'day', style = 'sex', size = 'time',height=5,aspect=2)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', col = 'sex',data = tips)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size = 'size', style = 'time')

# %% [markdown]
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - Countplot()
# - etc...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x="sex",data=tips,palette="cool")

# %%
#catplot()

# %%
sns.catplot(x = 'time', y = 'total_bill', data = tips,kind="box",height=5,aspect=2.5)

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips,aspect=2.5,hue="time",kind="boxen")

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()

# %%
sns.catplot(x = 'cut', y = 'price',kind="box",hue="clarity",data=diamonds,height=5,aspect=2.5)

# %%
sns.catplot(y= 'total_bill', x = 'day', hue = 'sex', kind = 'box', data = tips,height=5,aspect=2.5)

# %%
titanic=pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.catplot(x = "Pclass",y="Fare", kind = 'box', data = titanic,height=5,aspect=2.5)

# %%
sns.catplot(x = 'Sex', kind = 'count', data = titanic, hue = 'Pclass',height=5,aspect=2.5)

# %%
sns.catplot(x = 'Sex',y="Fare", kind="box", data = titanic, hue = 'Pclass',height=5,aspect=2.5)

# %% [markdown]
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()

# %%
from numpy.random import rand,randn,randint

# %%
x = randn(100)
x
# Out:
# array([-1.83105313e+00,  1.01274445e+00, -1.39382478e+00,  1.76976106e+00,
#         1.06376413e+00,  1.66783447e+00, -9.03211980e-01, -7.48607406e-01,
#         7.37992673e-02, -5.92429204e-01,  5.90308446e-01, -1.34475071e+00,
#        -2.10442053e+00,  1.20747958e+00, -7.55295058e-01,  1.52320074e-01,
#        -2.19940901e-01,  1.50360477e-01,  1.41128478e+00,  8.85510339e-01,
#         3.84311722e-01, -6.50363242e-01,  1.72567690e+00,  1.32760153e+00,
#        -9.13728362e-01, -5.20090703e-01, -9.45893544e-01,  1.55225378e+00,
#        -6.60700816e-01, -6.40222295e-01, -1.87678192e+00,  1.34030400e-01,
#         1.39896982e+00,  1.26180783e+00, -1.07546010e+00, -1.68040959e+00,
#        -8.00139097e-01, -9.98975214e-01, -3.18782626e-01,  5.47903223e-01,
#        -2.46922600e-01,  7.61813109e-01,  1.32678293e+00,  1.48071747e+00,
#        -7.73374536e-02,  6.78422277e-02, -4.68426741e-01, -4.60363506e-02,
# ...

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(12,5))
sns.distplot(tips["total_bill"],kde=True)
plt.show()

# %%
plt.figure(figsize=(18,4))
sns.distplot(x,kde=True)
# Out:
# <Axes: ylabel='Density'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.distplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.jointplot(x = "total_bill", y="tip",data=tips,height=6,ratio=3,)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips,hue="time")

# %% [markdown]
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x = 'total_bill', y= 'tip',hue="sex", data = tips,height=8,aspect=2.5)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips,hue="sex", col = 'time', col_wrap=1, height = 6,aspect=2.5)
